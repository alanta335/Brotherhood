# %% [markdown]
# <a href="https://colab.research.google.com/github/alanta335/Brotherhood/blob/master/my%20first%20neural%20network.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow==2.0.0-alpha0

# %%
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
import pandas as pd
import sys
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
tf.__version__
# Out:
# '2.0.0-alpha0'

# %%
training_data = np.array([[0,0],[0,1],[1,0],[1,1]],"float32")
target_data = np.array([[0],[1],[1],[0]],"float32")

# %%
 model = tf.keras.models.Sequential()

 model.add(tf.keras.layers.Dense(4,input_dim=2,activation='relu'))
 model.add(tf.keras.layers.Dense(1, activation='sigmoid'))

# %%
model.compile(loss='mean_squared_error',
              optimizer='adam',
              metrics=['binary_accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense (Dense)                (None, 4)                 12
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 5
# ...
# Total params: 17
# Trainable params: 17
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(training_data,target_data,nb_epoch=500,verbose=2)
# Out:
# WARNING:tensorflow:The `nb_epoch` argument in `fit` has been renamed `epochs`.
# Epoch 1/500
# 4/4 - 0s - loss: 0.2500 - binary_accuracy: 0.5000
# Epoch 2/500
# 4/4 - 0s - loss: 0.2500 - binary_accuracy: 0.5000
# Epoch 3/500
# 4/4 - 0s - loss: 0.2500 - binary_accuracy: 0.5000
# Epoch 4/500
# 4/4 - 0s - loss: 0.2500 - binary_accuracy: 0.5000
# Epoch 5/500
# 4/4 - 0s - loss: 0.2500 - binary_accuracy: 0.5000
# Epoch 6/500
# 4/4 - 0s - loss: 0.2500 - binary_accuracy: 0.5000
# Epoch 7/500
# 4/4 - 0s - loss: 0.2500 - binary_accuracy: 0.5000
# Epoch 8/500
# 4/4 - 0s - loss: 0.2500 - binary_accuracy: 0.5000
# Epoch 9/500
# 4/4 - 0s - loss: 0.2500 - binary_accuracy: 0.5000
# Epoch 10/500
# 4/4 - 0s - loss: 0.2500 - binary_accuracy: 0.5000
# Epoch 11/500
# 4/4 - 0s - loss: 0.2500 - binary_accuracy: 0.5000
# Epoch 12/500
# 4/4 - 0s - loss: 0.2500 - binary_accuracy: 0.5000
# Epoch 13/500
# 4/4 - 0s - loss: 0.2500 - binary_accuracy: 0.5000
# Epoch 14/500
# ...

# %%
print (model.predict(training_data).round())
# Out:
# [[0.]
#  [0.]
#  [0.]
#  [0.]]

# %%
loss_curve = history.history["loss"]
acc_curve = history.history["binary_accuracy"]

plt.plot(loss_curve, label="Train")
plt.legend(loc='upper left')
plt.title("loss")
plt.show()

# %%
plt.plot(acc_curve, label="Train")
plt.legend(loc='upper left')
plt.title("Accuracy")
plt.show()
